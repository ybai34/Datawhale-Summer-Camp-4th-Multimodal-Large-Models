# %% [markdown]
# # 10条数据快速跑通
#
# 1. 进入 conda dj环境
#     ```bash
#     conda activate dj
#     ```
#
#
# 2. 安装相关工具和包
#     ```bash
#     apt update
#     apt -y install axel zip file
#     pip install modelscope
#     bash install.sh
#     ```
#
# 3. 获取数据集
#     ```bash
#     cd better_synth_baseline_autoDL
#     bash download.sh  ###大概需要50分钟
#     ```
#
# 4. 下载BLIP模型
#     ```bash
#     python3 download_blip.py
#     ```
#
# 5. 处理数据集(这里只有10条)
#     ```bash
#     cd better_synth_baseline_autoDL
#     dj-process --config ./image_split_10.yaml
#     dj-process --config ./image_captioning_10.yaml
#     ```
#
# 6. 训练模型 & 评测
#     ```bash
#     bash train_mgm_2b_stage_1.sh
#     ```
#
# 7. 打包结果文件
#     ```bash
#     cd submit
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/solution .
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/output/eval_results output
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/output/train.sh output/
#
#     cp /root/autodl-tmp/better_synth_baseline_autoDL/output/training_dirs/MGM-2B-Finetune-image_recaption/finetuning.log output/training_dirs/MGM-2B-Finetune-image_recaption/
#
#     cp /root/autodl-tmp/better_synth_baseline_autoDL/output/training_dirs/MGM-2B-Pretrain-image_recaption/pretrain.log output/training_dirs/MGM-2B-Pretrain-image_recaption/
#
#     zip -r submit.zip solution output
#     ```

# %% [markdown]
# # 10k baseline 命令
#
# 注：若想要运行完整 10k baselin，请确保你至少有 110G 的CPU内存，以及40G的显存。
#
# 1. 进入 conda dj环境
#     ```bash
#     conda activate dj
#     ```
#
#
# 2. 安装相关工具和包
#     ```bash
#     apt update
#     apt -y install axel zip file
#     pip install modelscope
#     bash install.sh
#     ```
#
# 3. 获取数据集
#     ```bash
#     cd better_synth_baseline_autoDL
#     bash download.sh  ###大概需要50分钟
#     ```
#
# 4. 下载BLIP模型
#     ```bash
#     python3 download_blip.py
#     ```
#
# 5. 处理数据集
#     ```bash
#     dj-process --config solution/image_captioning.yaml
#     ```
#
# 6. 训练模型 & 评测
#     ```bash
#     bash train_mgm_2b_stage_1.sh
#     ```
#
# 7. 打包结果文件
#     ```bash
#     cd submit
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/solution .
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/output/eval_results output
#
#     cp -r /root/autodl-tmp/better_synth_baseline_autoDL/output/train.sh output/
#
#     cp /root/autodl-tmp/better_synth_baseline_autoDL/output/training_dirs/MGM-2B-Finetune-image_recaption/finetuning.log output/training_dirs/MGM-2B-Finetune-image_recaption/
#
#     cp /root/autodl-tmp/better_synth_baseline_autoDL/output/training_dirs/MGM-2B-Pretrain-image_recaption/pretrain.log output/training_dirs/MGM-2B-Pretrain-image_recaption/
#
#     zip -r submit.zip solution output
#     ```
